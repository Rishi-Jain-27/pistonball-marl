# %% [markdown]
# # Code for training

# %%
# !git clone https://github.com/Rishi-Jain-27/pistonball-marl
# %cd pistonball-marl
# %pip install -r requirements.txt
# !python src/IDQN/idqn_agent.py idqnpistonball_1 --train
